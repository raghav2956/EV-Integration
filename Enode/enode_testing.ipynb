# %%
import requests
from requests.auth import HTTPBasicAuth
import json

# %% [markdown]
# ## Get Access Token

# %%
# Replace these with your actual client ID and client secret
client_id = 'fd9214df-119c-4444-8f77-5138b9c0d44a'
client_secret = 'f92a87b2fd96fdc96e4ea97a7b45af9923b0195d'

#https://enode-api.production.enode.io/

# Define the URL and the payload
url = 'https://oauth.production.enode.io/oauth2/token'
payload = {
    'grant_type': 'client_credentials'
}

# Make the POST request with basic authentication
response = requests.post(url, auth=HTTPBasicAuth(client_id, client_secret), data=payload)

# Check if the request was successful
if response.status_code == 200:
    token_data = response.json()
    print(token_data)
    access_token = token_data['access_token']
    print(f"Access Token: {access_token}")
else:
    # Print an error message if the request failed
    print(f"Failed to retrieve token: {response.status_code}, {response.text}")
# Out:
# {'access_token': 'mwrAg84DwOcOanZrAPdDgPTHq47Iq3u89RxfWBqGxgA.Pkk57ipZQv9ZyWYcfqBboD_SSErF8__MAcz52gLV1J8', 'expires_in': 3599, 'scope': '', 'token_type': 'bearer'}
# Access Token: mwrAg84DwOcOanZrAPdDgPTHq47Iq3u89RxfWBqGxgA.Pkk57ipZQv9ZyWYcfqBboD_SSErF8__MAcz52gLV1J8

# %% [markdown]
# ## Get Link URL to link Vehicle (Nissan)

# %%
# Define the URL and headers
# I make a new user for each new vehicle and charger. 
# Otherwise you can link multiple cars/chargers to one user.
url_nissan = 'https://enode-api.production.enode.io/users/nissan/link'

headers = {
    'Authorization': f'Bearer {access_token}',
    'Content-Type': 'application/json'
}

# Define the payload
vehicle_payload = {
    "vendorType": "vehicle",
    "scopes": [
        "vehicle:read:data",
        "vehicle:read:location",
        "vehicle:control:charging"
    ],
    "language": "en-US",
    "redirectUri": "https://localhost:3000"
}


# Make the POST request
vehicle_response_nissan = requests.post(url_nissan, headers=headers, json=vehicle_payload)

# Check if the request was successful
if vehicle_response_nissan.status_code == 200:
    # Print the response JSON if the request was successful
    print(vehicle_response_nissan.json())
else:
    # Print an error message if the request failed
    print(f"Failed to link user: {vehicle_response_nissan.status_code}, {vehicle_response_nissan.text}")
# Out:
# {'linkUrl': 'https://link.enode....%3D', 'linkToken': '...'}

# %% [markdown]
# ## Link Porsche to a new User

# %%
## # Define the URL and headers
url = 'https://enode-api.production.enode.io/users/porsche/link'
headers = {
    'Authorization': f'Bearer {access_token}',
    'Content-Type': 'application/json'
}

# Define the payload
vehicle_payload = {
    "vendorType": "vehicle",
    "scopes": [
        "vehicle:read:data",
        "vehicle:read:location",
        "vehicle:control:charging"
    ],
    "language": "en-US",
    "redirectUri": "https://localhost:3000"
}

# Make the POST request
vehicle_response_porsche = requests.post(url, headers=headers, json=vehicle_payload)

# Check if the request was successful
if vehicle_response_porsche.status_code == 200:
    # Print the response JSON if the request was successful
    print(vehicle_response_porsche.json())
else:
    # Print an error message if the request failed
    print(f"Failed to link user: {vehicle_response_porsche.status_code}, {vehicle_response_porsche.text}")

# %% [markdown]
# ## Link VW Golf

# %%
## # Define the URL and headers
url = 'https://enode-api.production.enode.io/users/vw_golf/link'
headers = {
    'Authorization': f'Bearer {access_token}',
    'Content-Type': 'application/json'
}

# Define the payload
vehicle_payload = {
    "vendorType": "vehicle",
    "scopes": [
        "vehicle:read:data",
        "vehicle:read:location",
        "vehicle:control:charging"
    ],
    "language": "en-US",
    "redirectUri": "https://localhost:3000"
}

# Make the POST request
vehicle_response_porsche = requests.post(url, headers=headers, json=vehicle_payload)

# Check if the request was successful
if vehicle_response_porsche.status_code == 200:
    # Print the response JSON if the request was successful
    print(vehicle_response_porsche.json())
else:
    # Print an error message if the request failed
    print(f"Failed to link user: {vehicle_response_porsche.status_code}, {vehicle_response_porsche.text}")
# Out:
# {'linkUrl': 'https://link.enode....', 'linkToken': '...'}

# %% [markdown]
# ## Link Zaptec

# %%
## # Define the URL and headers
url = 'https://enode-api.production.enode.io/users/zaptec/link'
headers = {
    'Authorization': f'Bearer {access_token}',
    'Content-Type': 'application/json'
}

# Define the payload
charger_payload = {
    "vendorType": "charger",
    "scopes": [
        "charger:control:charging",
        "charger:read:data"
    ],
    "language": "en-US",
    "redirectUri": "https://localhost:3000"
}

# Make the POST request
charger_response_zaptec = requests.post(url, headers=headers, json=charger_payload)


# Check if the request was successful
if charger_response_zaptec.status_code == 200:
    # Print the response JSON if the request was successful
    print(charger_response_zaptec.json())
else:
    # Print an error message if the request failed
    print(f"Failed to link user: {charger_response_zaptec.status_code}, {charger_response_zaptec.text}")
# Out:
# {'linkUrl': 'https://link.enode....%3D', 'linkToken': '...'}

# %% [markdown]
# ## Link Easee

# %%
## # Define the URL and headers
url = 'https://enode-api.production.enode.io/users/easee/link'
headers = {
    'Authorization': f'Bearer {access_token}',
    'Content-Type': 'application/json'
}

# Define the payload
charger_payload = {
    "vendorType": "charger",
    "scopes": [
        "charger:control:charging",
        "charger:read:data"
    ],
    "language": "en-US",
    "redirectUri": "https://localhost:3000"
}

# Make the POST request
charger_response_easee = requests.post(url, headers=headers, json=charger_payload)


# Check if the request was successful
if charger_response_easee.status_code == 200:
    # Print the response JSON if the request was successful
    print(charger_response_easee.json())
else:
    # Print an error message if the request failed
    print(f"Failed to link user: {charger_response_easee.status_code}, {charger_response_easee.text}")
# Out:
# {'linkUrl': 'https://link.enode....%3D', 'linkToken': '...'}

# %% [markdown]
# ## Link Easee 2 (Second Easee Charger)

# %%
## # Define the URL and headers
url = 'https://enode-api.production.enode.io/users/easee2/link'
headers = {
    'Authorization': f'Bearer {access_token}',
    'Content-Type': 'application/json'
}

# Define the payload
charger_payload = {
    "vendorType": "charger",
    "scopes": [
        "charger:control:charging",
        "charger:read:data"
    ],
    "language": "en-US",
    "redirectUri": "https://localhost:3000"
}

# Make the POST request
charger_response_easee = requests.post(url, headers=headers, json=charger_payload)


# Check if the request was successful
if charger_response_easee.status_code == 200:
    # Print the response JSON if the request was successful
    print(charger_response_easee.json())
else:
    # Print an error message if the request failed
    print(f"Failed to link user: {charger_response_easee.status_code}, {charger_response_easee.text}")
# Out:
# {'linkUrl': 'https://link.enode....%3D', 'linkToken': '...'}

# %% [markdown]
# ## Confirm user and vehicle/charger is linked

# %%
# Define the URL and headers
url = 'https://enode-api.production.enode.io/users/nissan'
headers = {
    'Authorization': f'Bearer {access_token}'
}

# Make the GET request
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Print the response JSON if the request was successful
    print(response.json())
else:
    # Print an error message if the request failed
    print(f"Failed to retrieve user data: {response.status_code}, {response.text}")

# %% [markdown]
# ## List all vehicles connected to Enode account

# %%
# Define your API URL and access token
api_url = "https://enode-api.production.enode.io//vehicles"

# Set up the headers with the authorization token
headers = {
    "Authorization": f"Bearer {access_token}"
}

# Make the GET request
response = requests.get(api_url, headers=headers)



# Check if the request was successful
if response.status_code == 200:
    response_json = response.json()
    
    # Pretty-print the JSON response
    print(json.dumps(response_json, indent=4))

    # Extract the vehicle ID from the response
    # vehicleId_porsche = response_json['data'][1]['id']
    # vehicleId_nissan = response_json['data'][0]['id']
    # userId_porsche = response_json['data'][1]['userId']
    # userId_nissan = response_json['data'][0]['userId']
    # locationId_porsche = response_json['data'][1]['locationId']
    # locationId_nissan = response_json['data'][0]['locationId']
    vehicleId_vw = response_json['data'][0]['id']
    userId_vw = response_json['data'][0]['userId']
    locationId_vw = response_json['data'][0]['locationId']
    # print(vehicleId_porsche)
    # print(vehicleId_nissan)

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)
# Out:
# {
#     "data": [
#         {
#             "id": "6c922f9b-7ee7-46cd-9998-bb8471d2f718",
#             "userId": "vw_golf",
#             "vendor": "VOLKSWAGEN",
#             "isReachable": false,
#             "lastSeen": "2024-09-09T14:51:55.987Z",
#             "information": {
#                 "displayName": null,
#                 "vin": "WVWZZZAUZFW907421",
#                 "brand": "Volkswagen",
#                 "model": "e-Golf",
#                 "year": 2015
#             },
#             "chargeState": {
#                 "chargeRate": null,
#                 "chargeTimeRemaining": null,
#                 "isFullyCharged": false,
#                 "isPluggedIn": false,
#                 "isCharging": false,
#                 "batteryLevel": 91,
#                 "range": 141,
#                 "batteryCapacity": 32,
#                 "chargeLimit": 100,
#                 "lastUpdated": "2024-09-09T09:06:37.000Z",
#                 "powerDeliveryState": "UNPLUGGED",
# ...

# %% [markdown]
# ## List all Chargers

# %%
# Define your API URL and access token
api_url = "https://enode-api.production.enode.io//chargers"

# Set up the headers with the authorization token
headers = {
    "Authorization": f"Bearer {access_token}"
}

# Make the GET request
response = requests.get(api_url, headers=headers)



# Check if the request was successful
if response.status_code == 200:
    response_json = response.json()
    
    # Pretty-print the JSON response
    print(json.dumps(response_json, indent=4))

    # Extract the charger ID from the response
    chargerId_easee2 = response_json['data'][0]['id']
    userId_easee2 = response_json['data'][0]['userId']
    locationId_easee2 = response_json['data'][0]['locationId']
    chargerId_zaptec = response_json['data'][1]['id']
    userId_zaptec = response_json['data'][1]['userId']
    locationId_zaptec = response_json['data'][1]['locationId']
    # print(chargerId)

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)
# Out:
# {
#     "data": [
#         {
#             "id": "41fe6d4d-d45c-4e25-a7bd-8f6fff36196f",
#             "userId": "easee2",
#             "vendor": "EASEE",
#             "lastSeen": "2024-09-10T12:56:39.539Z",
#             "isReachable": true,
#             "chargeState": {
#                 "isPluggedIn": true,
#                 "isCharging": true,
#                 "powerDeliveryState": "PLUGGED_IN:CHARGING",
#                 "chargeRate": 1.25,
#                 "lastUpdated": "2024-09-10T12:49:44.000Z",
#                 "maxCurrent": 32
#             },
#             "information": {
#                 "brand": "Easee",
#                 "model": "Charge",
#                 "year": null
#             },
#             "capabilities": {
#                 "information": {
#                     "interventionIds": [],
#                     "isCapable": true
#                 },
#                 "chargeState": {
#                     "interventionIds": [],
# ...

# %% [markdown]
# ## Refresh Vehicle Data

# %%
# Define the base API URL
base_api_url = "https://enode-api.production.enode.io/"

# vehicleId = vehicleId_
# Define the dynamic part of the URL
dynamic_endpoint = f"/vehicles/{vehicleId}/refresh-hint"  # Replace this with your dynamic endpoint

# Combine the base URL with the dynamic endpoint
api_url = base_api_url + dynamic_endpoint

# Set up the headers with the authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}


# Make the GET request
response = requests.post(api_url, headers=headers)

# Check if the request was successful
if response.status_code == 204:
    print('Vehicle Data Refreshed!')
    # response_json = response.json()
    # # Print the JSON response from the API
    # print(response_json)

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       2 base_api_url = "https://enode-api.production.enode.io/"
#       4 # vehicleId = vehicleId_
#       5 # Define the dynamic part of the URL
# ----> 6 dynamic_endpoint = f"/vehicles/{vehicleId}/refresh-hint"  # Replace this with your dynamic endpoint
#       8 # Combine the base URL with the dynamic endpoint
#       9 api_url = base_api_url + dynamic_endpoint
#
# NameError: name 'vehicleId' is not defined

# %% [markdown]
# ## Refresh Charger Data

# %%
# Define the base API URL
base_api_url = "https://enode-api.production.enode.io/"

chargerId = chargerId_easee2
# Define the dynamic part of the URL
dynamic_endpoint = f"/chargers/{chargerId}/refresh-hint"  # Replace this with your dynamic endpoint

# Combine the base URL with the dynamic endpoint
api_url = base_api_url + dynamic_endpoint

# Set up the headers with the authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}


# Make the GET request
response = requests.post(api_url, headers=headers)

# Check if the request was successful
if response.status_code == 204:
    print('Data Refreshed!')
    # response_json = response.json()
    # # Print the JSON response from the API
    # print(response_json)

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)
# Out:
# Data Refreshed!

# %% [markdown]
# ## Start Charge (Vehicle Side)

# %%
# Define the base API URL
base_api_url = "https://enode-api.production.enode.io/"

vehicleId = vehicleId_vw
# Define the dynamic part of the URL
dynamic_endpoint = f"vehicles/{vehicleId}/charging"  # Replace this with your dynamic endpoint

# Combine the base URL with the dynamic endpoint
api_url = base_api_url + dynamic_endpoint

# Set up the headers with the authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# Define the data payload for the request
data = {"action": "START"}

# Make the GET request
response = requests.post(api_url, headers=headers, json=data)

# Check if the request was successful
if response.status_code == 200:
    response_json = response.json()
    
    # Pretty-print the JSON response
    print(json.dumps(response_json, indent=4))
    actionId = response_json['id']

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)
# Out:
# {
#     "id": "fbc150b7-842d-4b45-aad2-b64dffee7f44",
#     "userId": "vw_golf",
#     "state": "PENDING",
#     "createdAt": "2024-09-06T17:34:38.430Z",
#     "updatedAt": "2024-09-06T17:34:38.430Z",
#     "completedAt": null,
#     "targetId": "6c922f9b-7ee7-46cd-9998-bb8471d2f718",
#     "targetType": "vehicle",
#     "kind": "START",
#     "failureReason": null
# }

# %% [markdown]
# ## Stop Charge (Vehicle Side)

# %%
# Define the base API URL
base_api_url = "https://enode-api.production.enode.io/"

# vehicleId = vehicleId_nissan
vehicleId = vehicleId_vw

# Define the dynamic part of the URL
dynamic_endpoint = f"vehicles/{vehicleId}/charging"  # Replace this with your dynamic endpoint

# Combine the base URL with the dynamic endpoint
api_url = base_api_url + dynamic_endpoint

# Set up the headers with the authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# Define the data payload for the request
data = {"action": "STOP"}

# Make the GET request
response = requests.post(api_url, headers=headers, json=data)

# Check if the request was successful
if response.status_code == 200:
    response_json = response.json()
    
    # Pretty-print the JSON response
    print(json.dumps(response_json, indent=4))
    actionId = response_json['id']

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)
# Out:
# {
#     "id": "3e663ad1-82ff-4064-9600-d6eb37b29756",
#     "userId": "vw_golf",
#     "state": "PENDING",
#     "createdAt": "2024-09-06T17:30:53.617Z",
#     "updatedAt": "2024-09-06T17:30:53.617Z",
#     "completedAt": null,
#     "targetId": "6c922f9b-7ee7-46cd-9998-bb8471d2f718",
#     "targetType": "vehicle",
#     "kind": "STOP",
#     "failureReason": null
# }

# %% [markdown]
# ## Start Charge (Charger Side)

# %%
# Define the base API URL
base_api_url = "https://enode-api.production.enode.io/"

# vehicleId = vehicleId_nissan
chargerId = chargerId_easee2
# Define the dynamic part of the URL
dynamic_endpoint = f"chargers/{chargerId}/charging"  # Replace this with your dynamic endpoint

# Combine the base URL with the dynamic endpoint
api_url = base_api_url + dynamic_endpoint

# Set up the headers with the authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# Define the data payload for the request
data = {"action": "START"}

# Make the GET request
response = requests.post(api_url, headers=headers, json=data)

# Check if the request was successful
if response.status_code == 200:
    response_json = response.json()
    
    # Pretty-print the JSON response
    print(json.dumps(response_json, indent=4))
    actionId = response_json['id']

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)
# Out:
# Failed to fetch data. Status code: 400
# {"type":"https://docs.enode.io/problems/bad-request","title":"Already charging","detail":"The entity you provided is already charging.","error":"https://docs.enode.io/problems/bad-request","message":"The entity you provided is already charging."}

# %% [markdown]
# ## Stop Charge (Charger Side)

# %%
# Define the base API URL
base_api_url = "https://enode-api.production.enode.io/"

# vehicleId = vehicleId_nissan
chargerId = chargerId_easee2
# Define the dynamic part of the URL
dynamic_endpoint = f"chargers/{chargerId}/charging"  # Replace this with your dynamic endpoint

# Combine the base URL with the dynamic endpoint
api_url = base_api_url + dynamic_endpoint

# Set up the headers with the authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# Define the data payload for the request
data = {"action": "STOP"}

# Make the GET request
response = requests.post(api_url, headers=headers, json=data)

# Check if the request was successful
if response.status_code == 200:
    response_json = response.json()
    
    # Pretty-print the JSON response
    print(json.dumps(response_json, indent=4))
    actionId = response_json['id']

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)
# Out:
# {
#     "id": "deb1a5c8-466a-4283-80cb-d4c645841e98",
#     "userId": "easee2",
#     "state": "PENDING",
#     "createdAt": "2024-09-10T14:26:25.834Z",
#     "updatedAt": "2024-09-10T14:26:25.834Z",
#     "completedAt": null,
#     "targetId": "41fe6d4d-d45c-4e25-a7bd-8f6fff36196f",
#     "targetType": "charger",
#     "kind": "STOP",
#     "failureReason": null
# }

# %% [markdown]
# ## Get Action Status

# %%
# Define the base API URL
base_api_url = "https://enode-api.production.enode.io/"

# actionId = "7112db23-247e-4765-aee9-c28eea3dc354"
# Define the dynamic part of the URL
# dynamic_endpoint = f"/vehicles/actions/{actionId}"  # Replace this with your dynamic endpoint
dynamic_endpoint = f"/chargers/actions/{actionId}"
# Combine the base URL with the dynamic endpoint
api_url = base_api_url + dynamic_endpoint

# Set up the headers with the authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}


# Make the GET request
response = requests.get(api_url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    response_json = response.json()
    
    # Pretty-print the JSON response
    print(json.dumps(response_json, indent=4))

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)
# Out:
# {
#     "id": "1c5c404c-b903-457c-8ab2-1aef5e21daac",
#     "userId": "easee2",
#     "state": "CONFIRMED",
#     "createdAt": "2024-09-10T12:03:51.756Z",
#     "updatedAt": "2024-09-10T12:06:09.047Z",
#     "completedAt": "2024-09-10T12:06:09.047Z",
#     "targetId": "41fe6d4d-d45c-4e25-a7bd-8f6fff36196f",
#     "targetType": "charger",
#     "kind": "STOP",
#     "failureReason": null
# }

# %% [markdown]
# ## Cancel Action

# %%
# Define the base API URL
base_api_url = "https://enode-api.production.enode.io/"

# actionId = "7112db23-247e-4765-aee9-c28eea3dc354"
# Define the dynamic part of the URL
# dynamic_endpoint = f"/vehicles/actions/{actionId}"  # Replace this with your dynamic endpoint
dynamic_endpoint = f"/chargers/actions/{actionId}/cancel"
# Combine the base URL with the dynamic endpoint
api_url = base_api_url + dynamic_endpoint

# Set up the headers with the authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}


# Make the GET request
response = requests.post(api_url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    response_json = response.json()
    
    # Pretty-print the JSON response
    print(json.dumps(response_json, indent=4))

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)
# Out:
# {
#     "id": "884afc30-b079-4a0a-8a39-9dc474212b5e",
#     "userId": "nissan",
#     "state": "CANCELLED",
#     "createdAt": "2024-09-05T17:46:47.888Z",
#     "updatedAt": "2024-09-05T17:47:11.421Z",
#     "completedAt": "2024-09-05T17:47:11.421Z",
#     "targetId": "4b2f6297-7b37-4a6e-89e3-dbfcd4506311",
#     "targetType": "vehicle",
#     "kind": "START",
#     "failureReason": {
#         "type": "REQUESTED_CANCELLATION",
#         "detail": "The action was cancelled following an external request."
#     }
# }

# %% [markdown]
# ## Get Locations of devices linked to Enode account

# %%
# Define the dynamic part of the URL
dynamic_endpoint = f"/locations"  # Replace this with your dynamic endpoint

# Combine the base URL with the dynamic endpoint
api_url = base_api_url + dynamic_endpoint

# Set up the headers with the authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}


# Make the GET request
response = requests.get(api_url, headers=headers)



# Check if the request was successful
if response.status_code == 200:
    response_json = response.json()
    # Print the JSON response from the API
    print(response_json)

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)
# Out:
# {'data': [{'id': '4a54b40c-5bb3-4356-b3ac-9842f0eaf3e3', 'userId': 'porsche', 'name': 'test_location', 'longitude': 10.63582, 'latitude': 59.95666, 'timezoneName': 'Europe/Oslo'}, {'id': '83361f82-78e5-43f3-9d6e-2fb915088327', 'userId': 'zaptec', 'name': 'test_location', 'longitude': 10.63582, 'latitude': 59.95666, 'timezoneName': 'Europe/Oslo'}, {'id': 'e30a456b-5cdb-4dd5-ac1c-9e5ef2fb450a', 'userId': 'porsche', 'name': 'test_location', 'longitude': 10.636214, 'latitude': 59.956572, 'timezoneName': 'Europe/London'}], 'pagination': {'after': None, 'before': None}}

# %% [markdown]
# ## Set Location on User ID (not per charger or vehicle)

# %%
userId = userId_easee2

# Define the dynamic part of the URL
dynamic_endpoint = f"/users/{userId}/locations"  # Replace this with your dynamic endpoint

# Combine the base URL with the dynamic endpoint
api_url = base_api_url + dynamic_endpoint

# Set up the headers with the authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

data = {
    'name': 'easee_location',
    'latitude': 59.95666,
    'longitude': 10.63582,
    'timezoneName': "Europe/Oslo"
}

# Make the GET request
response = requests.post(api_url, headers=headers, json=data)



# Check if the request was successful
if response.status_code == 200:
    response_json = response.json()
    # Print the JSON response from the API
    print(response_json)
    locationId = response_json['id']
    print(locationId)

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)
# Out:
# {'id': 'f6bf14ed-957c-448b-b848-473ce4e8256a', 'userId': 'easee2', 'name': 'easee_location', 'longitude': 10.63582, 'latitude': 59.95666, 'timezoneName': 'Europe/Oslo'}
# f6bf14ed-957c-448b-b848-473ce4e8256a

# %% [markdown]
# ## Delete Locations

# %%
userId = userId_porsche
locationId = '19129253-c579-446e-be35-c356037cc7ed'
# Define the dynamic part of the URL
dynamic_endpoint = f"/locations/{locationId}"  # Replace this with your dynamic endpoint

# Combine the base URL with the dynamic endpoint
api_url = base_api_url + dynamic_endpoint

# Set up the headers with the authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# Make the GET request
response = requests.delete(api_url, headers=headers)



# Check if the request was successful
if response.status_code == 200:
    response_json = response.json()
    # Print the JSON response from the API
    print(response_json)
    locationId = response_json['id']
    print(locationId)

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)

# %% [markdown]
# ## Set Schedule on a charger/vehicle

# %%
# userId = userId_porsche
# vehicleId = vehicleId_porsche

userId = userId_easee2
chargerId = chargerId_easee2

# Define the dynamic part of the URL
dynamic_endpoint = f"/users/{userId}/schedules"  # Replace this with your dynamic endpoint

# Combine the base URL with the dynamic endpoint
api_url = base_api_url + dynamic_endpoint

# Set up the headers with the authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# data = {
#   "isEnabled": True,
#   "defaultShouldCharge": False,
#   "rules": [
#     {
#       "shouldCharge": True,
#       "hourMinute": {
#         "from": "14:15",
#         "to": "14:30"
#       }},
#     {
#       "shouldCharge": True,
#       "hourMinute": {
#         "from": "14:45",
#         "to": "15:00"
#       }},

#       {
#       "shouldCharge": True,
#       "hourMinute": {
#         "from": "15:15",
#         "to": "15:30"
#       }},
#       "toTimestamp": "2024-09-06T17:00:00Z"
#     ],
#     "targetId": chargerId,
#     "targetType": "charger",
#     "locationId": locationId_easee
# }

data = {
    "isEnabled": True,
    "defaultShouldCharge": True,
    "rules": [
        # {"toTimestamp": "2024-09-06T17:00:00Z"},
        {
            "shouldCharge": False,
            "hourMinute": {
                "from": "14:30",
                "to": "14:45"
            }
        },
        # {
        #     "shouldCharge": True,
        #     "hourMinute": {
        #         "from": "16:00",
        #         "to": "16:30"
        #     }
        # },
        # {
        #     "shouldCharge": True,
        #     "hourMinute": {
        #         "from": "17:00",
        #         "to": "17:30"
        #     }
        # }
    ],
    "targetId": chargerId,  
    "targetType": "charger",
    "locationId": locationId_easee2
}



# Make the GET request
response = requests.post(api_url, headers=headers, json=data)

# Check if the request was successful
if response.status_code == 201:
    response_json = response.json()
    # Pretty-print the JSON response
    print(json.dumps(response_json, indent=4))
    scheduleId = response_json['id']

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)
# Out:
# {
#     "id": "9b9aa9ba-bcb9-4fc3-98dc-31918b4e93d7",
#     "locationId": "f6bf14ed-957c-448b-b848-473ce4e8256a",
#     "isEnabled": true,
#     "defaultShouldCharge": true,
#     "rules": [
#         {
#             "hourMinute": {
#                 "to": "14:45",
#                 "from": "14:30"
#             },
#             "shouldCharge": false
#         }
#     ],
#     "targetId": "41fe6d4d-d45c-4e25-a7bd-8f6fff36196f",
#     "targetType": "charger"
# }

# %% [markdown]
# ## Clear Charging Schedule

# %%
scheduleId = "9b9aa9ba-bcb9-4fc3-98dc-31918b4e93d7"

# Define the dynamic part of the URL
dynamic_endpoint = f"/schedules/{scheduleId}"  # Replace this with your dynamic endpoint

# Combine the base URL with the dynamic endpoint
api_url = base_api_url + dynamic_endpoint

# Set up the headers with the authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}


# Make the GET request
response = requests.delete(api_url, headers=headers, json=data)

# Check if the request was successful
if response.status_code == 204:
    print('Schedule Cleared')

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)
# Out:
# Schedule Cleared

# %% [markdown]
# ## Get User Schedule

# %%
userId = userId_porsche

# Define the dynamic part of the URL
dynamic_endpoint = f"/users/{userId}/schedules"  # Replace this with your dynamic endpoint

# Combine the base URL with the dynamic endpoint
api_url = base_api_url + dynamic_endpoint

# Set up the headers with the authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}


# Make the GET request
response = requests.get(api_url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    response_json = response.json()
    # Pretty-print the JSON response
    print(json.dumps(response_json, indent=4))
 

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)
# Out:
# {
#     "data": [],
#     "pagination": {
#         "after": null,
#         "before": null
#     }
# }

# %% [markdown]
# ## Create Smart Override

# %%
userId = userId_porsche

# Define the dynamic part of the URL
dynamic_endpoint = f"/vehicles/{vehicleId}/smart-override"  # Replace this with your dynamic endpoint

# Combine the base URL with the dynamic endpoint
api_url = base_api_url + dynamic_endpoint

# Set up the headers with the authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}



# Make the GET request
response = requests.post(api_url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    response_json = response.json()
    
    # Pretty-print the JSON response
    print(json.dumps(response_json, indent=4))

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)
# Out:
# Failed to fetch data. Status code: 400
# {"type":"https://docs.enode.io/problems/bad-request","title":"No Smart Feature to Override","detail":"The smart override isn't overriding a smart feature. To control charging, use the standard Control Endpoints instead.","error":"https://docs.enode.io/problems/bad-request","message":"The smart override isn't overriding a smart feature. To control charging, use the standard Control Endpoints instead."}

# %% [markdown]
# ## End Smart Override

# %%
userId = userId_porsche

# Define the dynamic part of the URL
dynamic_endpoint = f"/vehicles/{vehicleId}/smart-override"  # Replace this with your dynamic endpoint

# Combine the base URL with the dynamic endpoint
api_url = base_api_url + dynamic_endpoint

# Set up the headers with the authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}



# Make the GET request
response = requests.delete(api_url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    response_json = response.json()
    
    # Pretty-print the JSON response
    print(json.dumps(response_json, indent=4))

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)

# %% [markdown]
# ## Get Statistics

# %%
userId = userId_zaptec

# Define the dynamic part of the URL
dynamic_endpoint = f"/users/{userId}/statistics/charging"  # Replace this with your dynamic endpoint
# dynamic_endpoint = f"/users/{userId}/statistics/charging/sessions"  # Replace this with your dynamic endpoint

# Combine the base URL with the dynamic endpoint
api_url = base_api_url + dynamic_endpoint

# Set up the headers with the authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# Define the query parameters
data = {
    "startDate": "2024-09-09T13:00.000Z",  # Required
    "endDate": "2024-09-09T15:30:00.000Z",    # Optional
    # "locationId": locationId_zaptec,         # Optional
    "id": chargerId_zaptec,                   # Optional
    "type": "charger",                       # Required; Possible values: "charger", "vehicle", "hvac"
    "resolution": "HALF_HOUR"
}


# Make the GET request
response = requests.get(api_url, headers=headers, params=data)

# Check if the request was successful
if response.status_code == 200:
    response_json = response.json()
    
    # Pretty-print the JSON response
    print(json.dumps(response_json, indent=4))

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)
# Out:
# [
#     {
#         "kw": {
#             "min": 6.02,
#             "max": 6.02,
#             "mean": 6.02
#         },
#         "kwhSum": 2.51,
#         "price": {
#             "min": 0,
#             "max": 0,
#             "mean": 0
#         },
#         "costSum": 0,
#         "nonSmartPrice": {
#             "min": 0,
#             "max": 0,
#             "mean": 0
#         },
#         "estimatedSavings": 0,
#         "date": "2024-09-09T13:00:00.000Z"
#     },
#     {
#         "kw": {
#             "min": 0,
#             "max": 0,
#             "mean": 0
#         },
#         "kwhSum": 0,
#         "price": {
#             "min": 0,
#             "max": 0,
#             "mean": 0
#         },
#         "costSum": 0,
#         "nonSmartPrice": {
#             "min": 0,
#             "max": 0,
#             "mean": 0
#         },
#         "estimatedSavings": 0,
#         "date": "2024-09-09T13:30:00.000Z"
#     },
#     {
#         "kw": {
#             "min": 1.42,
# ...

# %% [markdown]
# ## Delete UserId

# %%
# Define the base API URL
base_api_url = "https://enode-api.production.enode.io/"

userId = userId_nissan
# Define the dynamic part of the URL
dynamic_endpoint = f"/users/nissan"  # Replace this with your dynamic endpoint

# Combine the base URL with the dynamic endpoint
api_url = base_api_url + dynamic_endpoint

# Set up the headers with the authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}


# Make the GET request
response = requests.delete(api_url, headers=headers)

# Check if the request was successful
if response.status_code == 204:
    response_json = response.json()
    # Print the JSON response from the API
    print(response_json)

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)
# Out:
# Failed to fetch data. Status code: 404
# {"type":"https://docs.enode.io/problems/not-found","title":"User Not Found","detail":"User nissan not found"}
